# %%
print("hello world")
# Out:
# hello world

# %%
#task1
n1=float(input('enter any number: '))
n2=float(input('enter another number: '))
s=n1+n2
print("summation:",s)
p=n1*n2
print('product:',p)
d=n1/n2
print('division:',d)
# Out:
# enter any number: 5
# enter another number: 5
# summation: 10.0
# product: 25.0
# division: 1.0

# %%
va1=input("enter something to say: ")
va2=type(va1)
print(va2)
# Out:
# enter something to say: hi
# <class 'str'>

# %%
#task1
var1=float(input("please enter the first number: "))
var2=float(input("please enter the second number: "))# (=) mane assignment
sum=var1+var2
print("summation: ",sum)
prdct=var1*var2
print("product: ",prdct)
difference=var1-var2
print("Difference: ",difference)
# Out:
# please enter the first number: 5
# please enter the second number: 6
# summation:  11.0
# product:  30.0
# Difference:  -1.0

# %%
#TASK2
import math
radius=input("please enter radius: ")
radius=float(radius)
c=2*math.pi*radius
print("the circumference is ",c)
a=math.pi*radius*radius #we can use math.pi*radius**2 othoba math.pi*math.pow(radius,2)
print("the area is ",a)
# Out:
# please enter radius: 3.5
# the circumference is  21.991148575128552
# the area is  38.48451000647496

# %%
#task3
n1=float(input("enter any number: "))
n2=float(input("enter another number: "))
if(n1>n2):
  print("first is greater")
elif(n1<n2):
  print("second is greater")
else:
  print("the numbers are equal")
# Out:
# enter any number: 7
# enter another number: 7
# the numbers are equal

# %%
#task 4
n1=float(input('enter any number: '))
n2=float(input('enter another number: '))
if(n1<n2):
  print(n2-n1)
elif(n1>n2):
  print(n1-n2)
elif(n1==n2):
  print(n1-n2)
# Out:
# enter any number: -4
# enter another number: -40
# 36.0

# %%
#task5
n1=int(input("enter any number: "))
if(n1%2==0):
  print("the number is even")
else:
  print("the number is odd")
# Out:
# enter any number: 99
# the number is odd

# %%
#task6
var1=int(input("enter any number "))
if(var1%5==0 or var1%2==0):
  print("the number is a multiple of 2 or 5")
else:
  print("the number is not a multipe of 2 or 5")
# Out:
# enter any number 9
# the number is not a multipe of 2 or 5

# %%
#task7
var1=int(input('enter any number: '))
if(var1%5==0 and var1%2==0):
  print("the number is multiple of both 2 and 5")
elif(var1%5==0 or var1%2==0):
  print("the number is multiple of 2 or 5")
else:
  print("not the number we want")
# Out:
# enter any number: 4
# the number is multiple of 2 or 5

# %%
#task8
var1=int(input('enter any number: '))
if(var1%5==0 and var1%2==0):
  print("the number is multiple of both 2 and 5")
else:
  print("not the number multiple of 2 and 5 both")
# Out:
# enter any number: 6
# not the number multiple of 2 and 5 both

# %%
#task9
s=int(input('enter any number: '))
s1=s//3600
s2=s%3600
s3=s2//60
s4=s2%60
print('hours: ',s1)
print('minutes: ',s3) 
print('seconds: ',s4)
# Out:
# enter any number: 10000
# hours:  2
# minutes:  46
# seconds:  40

# %%
#task 10
h=int(input('enter the hours worked: '))
if (h<0):
  print('hours can not be negative')
elif(h>168):
  print('impossible to work more than 168 hours weekly')
elif (h>40):
  print('the persons weekly salary is: ',8000+(h-40)*300)
elif(h<=40):
  print('the persons weekly salary is: ',h*200)
# Out:
# enter the hours worked: 170
# impossible to work more than 168 hours weekly

# %%
#task11
s=int(input('enter any number: '))
if(s<100):
  print('L=',3000-125*s*s)
elif(s>=100):
  print('L=',12000/(4+(s*s)/14900))
# Out:
# enter any number: 120
# L= 2416.2162162162163

# %%
#task12
h=int(input('tell the hour: '))
if(h<0 or h>23):
  print('wrong time')
elif(h>=4 and h<=6):
  print('breakfast')
elif(h>=12 and h<=13):
  print('lunch')
elif(h>=16 and h<=17):
  print('snacks')
elif(h>=19 and h<=20):
  print('dinner')
else:
  print('patience is a virtue')
# Out:
# tell the hour: 2
# patience is a virtue

# %%
#task13
m=int(input('please enter the mark: '))
if (m<0 or m>100):
  print('the mark is not valid')
elif (m>=90 and m<=100):
  print('the grade is A')
elif (m>=80 and m<=89):
  print('the grade is B')
elif (m>=70 and m<=79):
  print('the grade is C')
elif (m>=60 and m<=69):
  print('the grade is D')
elif (m>=50 and m<=59):
  print('the grade is E')
elif (m<50):
  print('the grade is F')
# Out:
# please enter the mark: 66
# the grade is D

# %%
#task 14
d=float(input('enter the distance: '))
t=float(input('enter the time: '))
speed=(d/t)*3.6
if(speed<60):
  print('Too slow. Needs more changes')
elif(speed>=60 and speed<=90 ):
  print('Velocity is OK. The car is ready!')
elif(speed>90):
  print('Too fast. Only a few changes should suffice')
# Out:
# enter the distance: 25400
# enter the time: 3600
# Too slow. Needs more changes

# %%
#task15
cg=float(input('enter your CGPA: '))
crdt=float(input('enter numbers of credits completed: '))
if (cg<3.80 or crdt<30):
  print('the student is not eligble for the waiver')
elif (cg>=3.80 and cg<=3.89 and crdt>=30):
  print('The student is eligible for a waiver of 25 percent.')
elif (cg>=3.90 and cg<=3.94 and crdt>=30):
  print('The student is eligible for a waiver of 50 percent.')
elif (cg>=3.95 and cg<=3.99 and crdt>=30):
  print('The student is eligible for a waiver of 75 percent.')
elif (cg==4.00 and crdt>=30):
  print('The student is eligible for a waiver of 100 percent.')
# Out:
# enter your CGPA: 3.97
# enter numbers of credits completed: 30
# The student is eligible for a waiver of 75 percent.
