# %%
mylist=[-5,34,17,54,74,-94,-71,1,166,-69]
index1=0
index2=0
index3=1
while index1<10:
  mylist[index1]=index1+1
  index2=0
  while index2<10:
    if index2%2==0:
      mylist[index1]=mylist[index1]+mylist[index2]+index1
    else:
      mylist[index1]=mylist[index2]-mylist[index1]-index2
    index2=index2+1
  print(mylist[index1])
  index1=index1+1
# Out:
# -485
# -517
# -609
# -482
# -736
# -314
# 256
# -244
# 1430
# -9

# %% [markdown]
# ***class notes***

# %%
d={'a':1, 'b':2, 'c':3}
for item in d.items():
  print(item)
  print(item[0],item[1])
# Out:
# ('a', 1)
# a 1
# ('b', 2)
# b 2

# %%
t=(1,2,3)
a,b,c=t
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
-8%7  #immediate choto ta vagfol e ante hbe..ekhane -8 er immediate  choto hoitese -14
# Out:
# 6

# %%
#task 1
a_tuple = ("The Institute", ("Best Mystery & Thriller", "The Silent Patient", 68821), 75717,
[1, 2, 3, 400, 5, 6, 7], ("Best Fiction", "The Testaments", 98291))
print(a_tuple[3][3])
# Out:
# 400

# %%
book_info = (
("Best Mystery & Thriller","The Silent Patient",68821),
("Best Horror","The Institute",75717),
("Best History & Biography","The five",31783 ),
("Best Fiction","The Testaments",98291)
)
for i in book_info:
  a,b,c=i
  print(c)
# Out:
# The Silent Patient won the 'Best Mystery & Thriller'category with 68821 votes
# The Institute won the 'Best Horror'category with 75717 votes
# The five won the 'Best History & Biography'category with 31783 votes
# The Testaments won the 'Best Fiction'category with 98291 votes

# %%
#task 6
t=('a', 'b', 'c', 'd', 'e', 'f', 'g', 'h')
l=list(t)
p=[]
for i in range (-1,-len(l)-1,-1):
  p.append(l[i])
print(tuple(p))
# Out:
# ('h', 'g', 'f', 'e', 'd', 'c', 'b', 'a')

# %%
#task7
d1={'Harry':15, 'Draco':8, 'Nevil':19}
d2={'Ginie':18, 'Luna': 14}
for i in d2:
  d1[i]=d2[i]
print(d1)
# Out:
# {'Harry': 15, 'Draco': 8, 'Nevil': 19, 'Ginie': 18, 'Luna': 14}

# %%
#task9
exam_marks = {'Cierra Vega': 175, 'Alden Cantrell': 200, 'Kierra Gentry': 165, 'Pierre Cox': 190}
n=int(input())
d={}
for a,b in exam_marks.items():
  if b>=n:
    d[a]=b
print(d)
# Out:
# 190
# {'Alden Cantrell': 200, 'Pierre Cox': 190}

# %%
exam_marks = {'Cierra Vega': 175, 'Alden Cantrell': 200, 'Kierra Gentry': 165, 'Pierre Cox': 190}
d={}
n=int(input())
for i in exam_marks:
  if exam_marks[i]>=n:
    d[i]=exam_marks[i]
print(d)
# Out:
# 190
# {'Alden Cantrell': 200, 'Pierre Cox': 190}

# %%
#task8

# %%
#task 11
s="Python programming is fun".lower()
d={}
for i in s:
  d[i]=1
print(d)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1, ' ': 1, 'r': 1, 'g': 1, 'a': 1, 'm': 1, 'i': 1, 's': 1, 'f': 1, 'u': 1}
